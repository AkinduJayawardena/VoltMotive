# %% [markdown]
# <a href="https://colab.research.google.com/github/AkinduJayawardena/VoltMotive/blob/main/Control/E20_176_A_T_R_Jayawardena_Control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Twin rotor system **

# %% [markdown]
# Task 1 -
# Twin rotor system dynamic model

# %% [markdown]
# Following Diagram show the different body frames with twin Rotor

# %%
from IPython.display import Image, display
display(Image('your_image.jpg'))

# %%
from google.colab import drive
drive.mount('/content/drive')
